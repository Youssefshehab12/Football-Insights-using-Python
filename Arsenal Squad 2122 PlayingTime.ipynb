# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

from PIL import Image
import urllib
import os

# %%
df = pd.read_csv('Arsenal squad 2122 playing time.csv', header=[1])
df
# Out:
#                        Player   Nation   Pos   Age  MP     Min  Mn/MP   Min%  \
# 0                 Bukayo Saka  eng ENG  FWMF  19.0  38  2978.0   78.0   87.1
# 1          Gabriel Dos Santos   br BRA    DF  23.0  35  3063.0   88.0   89.6
# 2              Aaron Ramsdale  eng ENG    GK  23.0  34  3060.0   90.0   89.5
# 3                   Ben White  eng ENG    DF  23.0  32  2880.0   90.0   84.2
# 4             Martin Ødegaard   no NOR    MF  22.0  36  2785.0   77.0   81.4
# 5                Granit Xhaka   ch SUI  MFDF  28.0  27  2327.0   86.0   68.0
# 6               Thomas Partey   gh GHA    MF  28.0  24  2028.0   85.0   59.3
# 7              Kieran Tierney  sct SCO    DF  24.0  22  1915.0   87.0   56.0
# 8            Emile Smith Rowe  eng ENG  MFFW  21.0  33  1921.0   58.0   56.2
# 9                  Martinelli   br BRA  FWMF  20.0  29  1860.0   64.0   54.4
# 10        Alexandre Lacazette   fr FRA  FWMF  30.0  30  1782.0   59.0   52.1
# 11          Takehiro Tomiyasu   jp JPN    DF  22.0  21  1679.0   80.0   49.1
# 12              Cédric Soares   pt POR    DF  29.0  21  1486.0   71.0   43.5
# 13               Nuno Tavares   pt POR    DF  21.0  22  1176.0   53.0   34.4
# 14       Albert Sambi Lokonga   be BEL    MF  21.0  19  1134.0   60.0   33.2
# 15  Pierre-Emerick Aubameyang   ga GAB    FW  32.0  14  1037.0   74.0   30.3
# 16                Rob Holding  eng ENG    DF  25.0  15   845.0   56.0   24.7
# 17              Eddie Nketiah  eng ENG    FW  22.0  21   835.0   40.0   24.4
# 18             Mohamed Elneny   eg EGY    MF  29.0  14   806.0   58.0   23.6
# 19               Nicolas Pépé   ci CIV  FWMF  26.0  20   696.0   35.0   20.4
# 20                 Bernd Leno   de GER    GK  29.0   4   360.0   90.0   10.5
# 21     Ainsley Maitland-Niles  eng ENG    MF  23.0   8   268.0   34.0    7.8
# 22                 Pablo Marí   es ESP    DF  27.0   2   180.0   90.0    5.3
# 23             Calum Chambers  eng ENG    DF  26.0   2   170.0   85.0    5.0
# 24             Sead Kolašinac   ba BIH    DF  28.0   2    91.0   46.0    2.7
# 25            Folarin Balogun  eng ENG    FW  20.0   2    70.0   35.0    2.0
# 26               Reiss Nelson  eng ENG    FW  21.0   1    20.0   20.0    0.6
# 27             Ryan Alebiousu  eng ENG    DF  19.0   0     NaN    NaN    NaN
# 28                   Zach Awe  eng ENG    DF  17.0   0     NaN    NaN    NaN
# 29               Miguel Azeez  eng ENG    MF  18.0   0     NaN    NaN    NaN
# 30            Héctor Bellerín   es ESP  DFMF  26.0   0     NaN    NaN    NaN
# 31               Mika Biereth   dk DEN    FW  18.0   0     NaN    NaN    NaN
# 32             Marcelo Flores   mx MEX    MF  17.0   0     NaN    NaN    NaN
# 33           Omari Hutchinson  eng ENG    DF  17.0   0     NaN    NaN    NaN
# 34            Karl Jakob Hein   ee EST    GK  19.0   0     NaN    NaN    NaN
# 35                  Alex Kirk  eng ENG    DF  18.0   0     NaN    NaN    NaN
# 36             Mazeed Ogungbo   ie IRL    DF  18.0   0     NaN    NaN    NaN
# 37             Arthur Okonkwo  eng ENG    GK  19.0   0     NaN    NaN    NaN
# 38         Salah Oulad M'Hand   nl NED    MF  17.0   0     NaN    NaN    NaN
# 39             Charlie Patino  eng ENG    MF  17.0   0     NaN    NaN    NaN
# 40                Zak Swanson  eng ENG    DF  20.0   0     NaN    NaN    NaN
# 41                Squad Total      NaN   NaN  24.4  38  3420.0   90.0  100.0
# 42             Opponent Total      NaN   NaN  26.9  38  3420.0   90.0  100.0
#
#      90s  Starts  ...   +/-  +/-90  On-Off  onxG  onxGA  xG+/-  xG+/-90  \
# 0   33.1      36  ...  13.0   0.39    0.39  53.7   39.7   14.0     0.42
# 1   34.0      35  ...  24.0   0.71    3.48  57.4   36.7   20.8     0.61
# 2   34.0      34  ...  21.0   0.62    2.62  56.7   38.5   18.2     0.53
# 3   32.0      32  ...  17.0   0.53    1.20  52.2   35.1   17.1     0.54
# 4   30.9      32  ...  14.0   0.45    0.59  50.4   35.0   15.4     0.50
# 5   25.9      27  ...  11.0   0.43    0.26  43.1   31.5   11.6     0.45
# 6   22.5      23  ...  15.0   0.67    0.79  35.7   25.9    9.8     0.43
# 7   21.3      22  ...  12.0   0.56    0.50  32.7   23.0    9.7     0.46
# 8   21.3      21  ...   0.0   0.00   -0.78  30.3   29.4    0.8     0.04
# 9   20.7      21  ...   9.0   0.44    0.20  32.9   22.2   10.7     0.52
# 10  19.8      20  ...  19.0   0.96    1.29  33.6   20.1   13.6     0.69
# 11  18.7      20  ...  10.0   0.54    0.38  27.6   22.7    4.9     0.26
# 12  16.5      16  ...  -5.0  -0.30   -1.14  26.0   24.4    1.6     0.10
# 13  13.1      13  ...   6.0   0.46    0.18  21.3   17.4    3.9     0.30
# 14  12.6      12  ...   0.0   0.00   -0.51  17.4   14.0    3.4     0.27
# 15  11.5      12  ...   1.0   0.09   -0.37  16.3   16.9   -0.6    -0.05
# 16   9.4       9  ...   4.0   0.43    0.11  13.9   12.5    1.5     0.16
# 17   9.3       8  ...   0.0   0.00   -0.45  15.9   13.8    2.1     0.23
# 18   9.0       8  ...   3.0   0.33   -0.01  15.8   14.4    1.4     0.15
# 19   7.7       5  ...   2.0   0.26   -0.10  13.2   10.6    2.6     0.34
# 20   4.0       4  ...  -8.0  -2.00   -2.62   3.1    8.5   -5.3    -1.33
# 21   3.0       2  ...  -2.0  -0.67   -1.10   4.1    5.5   -1.4    -0.47
# 22   2.0       2  ...  -4.0  -2.00   -2.47   1.8    4.3   -2.5    -1.26
# 23   1.9       2  ...  -7.0  -3.71   -4.26   1.0    5.1   -4.2    -2.22
# 24   1.0       1  ...  -5.0  -4.95   -5.43   0.1    3.8   -3.7    -3.64
# 25   0.8       1  ...  -1.0  -1.29   -1.66   0.4    1.0   -0.6    -0.74
# 26   0.2       0  ...  -1.0  -4.50   -4.87   0.7    0.7    0.1     0.27
# 27   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 28   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 29   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 30   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 31   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 32   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 33   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 34   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 35   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 36   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 37   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 38   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 39   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 40   NaN       0  ...   NaN    NaN     NaN   NaN    NaN    NaN      NaN
# 41  38.0     418  ...  13.0   0.34     NaN  59.8   47.0   12.9     0.34
# 42  38.0     418  ...   NaN    NaN     NaN  47.0   59.8  -12.9    -0.34
#
#     On-Off.1  Matches     -9999
# 0       0.66  Matches  bc7dc64d
# 1       2.61  Matches  67ac5bb8
# 2       1.87  Matches  466fb2c5
# 3       1.25  Matches  35e413f1
# 4       0.85  Matches  79300479
# 5       0.35  Matches  e61b8aee
# 6       0.24  Matches  529f49ab
# 7       0.27  Matches  fce2302c
# 8      -0.68  Matches  17695062
# 9       0.39  Matches  48a5a5d6
# 10      0.72  Matches  9dbb75ca
# 11     -0.15  Matches  b3af9be1
# 12     -0.43  Matches  839c14e1
# 13     -0.06  Matches  a65c844b
# 14     -0.10  Matches  1b4f1169
# 15     -0.56  Matches  d5dd5f1f
# 16     -0.24  Matches  d79a8c87
# 17     -0.14  Matches  a53649b7
# 18     -0.24  Matches  47a34c4f
# 19      0.00  Matches  57e3f0c7
# 20     -1.87  Matches  2628fd2b
# 21     -0.88  Matches  e3a5814e
# 22     -1.68  Matches  aa54ec6f
# 23     -2.69  Matches  dc6f5bdd
# 24     -4.09  Matches  3935e52e
# 25     -1.10  Matches  31822f8c
# 26     -0.07  Matches  c5bdb6e3
# 27       NaN  Matches  ce048fb8
# 28       NaN  Matches  7a0ae4f0
# 29       NaN  Matches  660e71be
# 30       NaN  Matches  f874dd44
# 31       NaN  Matches  a1d95db3
# 32       NaN  Matches  937b36b1
# 33       NaN  Matches  bd9553e6
# 34       NaN  Matches  aa81d8f8
# 35       NaN  Matches  ace36a62
# 36       NaN  Matches  bacf9d43
# 37       NaN  Matches  75834acc
# 38       NaN  Matches  b85c3273
# 39       NaN  Matches  e71aac2c
# 40       NaN  Matches  5b7381b5
# 41       NaN      NaN     -9999
# 42       NaN      NaN     -9999
#
# [43 rows x 28 columns]

# %%
df_1 = df[df['Min'] >= 1000].reset_index(drop=True)
df_1 = df_1[['Player', 'Pos', 'Min', 'MP', 'Starts', 'Subs', 'unSub']]
df_1
# Out:
#                        Player   Pos     Min  MP  Starts  Subs  unSub
# 0                 Bukayo Saka  FWMF  2978.0  38      36     2      0
# 1          Gabriel Dos Santos    DF  3063.0  35      35     0      0
# 2              Aaron Ramsdale    GK  3060.0  34      34     0      2
# 3                   Ben White    DF  2880.0  32      32     0      2
# 4             Martin Ødegaard    MF  2785.0  36      32     4      0
# 5                Granit Xhaka  MFDF  2327.0  27      27     0      0
# 6               Thomas Partey    MF  2028.0  24      23     1      0
# 7              Kieran Tierney    DF  1915.0  22      22     0      4
# 8            Emile Smith Rowe  MFFW  1921.0  33      21    12      2
# 9                  Martinelli  FWMF  1860.0  29      21     8      7
# 10        Alexandre Lacazette  FWMF  1782.0  30      20    10      5
# 11          Takehiro Tomiyasu    DF  1679.0  21      20     1      1
# 12              Cédric Soares    DF  1486.0  21      16     5     12
# 13               Nuno Tavares    DF  1176.0  22      13     9     16
# 14       Albert Sambi Lokonga    MF  1134.0  19      12     7     18
# 15  Pierre-Emerick Aubameyang    FW  1037.0  14      12     2      0
# 16                Squad Total   NaN  3420.0  38     418   110    232
# 17             Opponent Total   NaN  3420.0  38     418   110    235

# %%
df_1['InSquad'] = df_1['MP'] + df_1['unSub']
df_1 = df_1.sort_values(by='Min').reset_index(drop=True)
df_1 = df_1[~df_1['Pos'].isna()]
df_1['Starts_InSquad'] = [f'{x}/{y}' for x,y in zip(df_1['Starts'], df_1['InSquad'])]
df_1
# Out:
#                        Player   Pos     Min  MP  Starts  Subs  unSub  InSquad  \
# 0   Pierre-Emerick Aubameyang    FW  1037.0  14      12     2      0       14
# 1        Albert Sambi Lokonga    MF  1134.0  19      12     7     18       37
# 2                Nuno Tavares    DF  1176.0  22      13     9     16       38
# 3               Cédric Soares    DF  1486.0  21      16     5     12       33
# 4           Takehiro Tomiyasu    DF  1679.0  21      20     1      1       22
# 5         Alexandre Lacazette  FWMF  1782.0  30      20    10      5       35
# 6                  Martinelli  FWMF  1860.0  29      21     8      7       36
# 7              Kieran Tierney    DF  1915.0  22      22     0      4       26
# 8            Emile Smith Rowe  MFFW  1921.0  33      21    12      2       35
# 9               Thomas Partey    MF  2028.0  24      23     1      0       24
# 10               Granit Xhaka  MFDF  2327.0  27      27     0      0       27
# 11            Martin Ødegaard    MF  2785.0  36      32     4      0       36
# 12                  Ben White    DF  2880.0  32      32     0      2       34
# 13                Bukayo Saka  FWMF  2978.0  38      36     2      0       38
# 14             Aaron Ramsdale    GK  3060.0  34      34     0      2       36
# 15         Gabriel Dos Santos    DF  3063.0  35      35     0      0       35
#
#    Starts_InSquad
# 0           12/14
# 1           12/37
# 2           13/38
# 3           16/33
# 4           20/22
# 5           20/35
# 6           21/36
# 7           22/26
# 8           21/35
# 9           23/24
# 10          27/27
# 11          32/36
# 12          32/34
# 13          36/38
# 14          34/36
# 15          35/35

# %%
fig = plt.figure(figsize=(7,10), dpi=300)
ax = plt.subplot()

ncols = 5
nrows = df_1.shape[0]

ax.set_xlim(0, ncols + 1)
ax.set_ylim(0, nrows + 1)

positions = [0.10, 2.5, 3.5, 4.5, 5.5]
columns = ['Player', 'Pos', 'Min', 'MP', 'Starts_InSquad']

# Add table's main text
for i in range(nrows):
    for j, column in enumerate(columns):
        if j == 0:
            ha = 'left'
        else:
            ha = 'center'
        if column == 'Min':
            text_label = f'{df_1[column].iloc[i]:,.0f}'
            weight = 'bold'
        else:
            text_label = f'{df_1[column].iloc[i]}'
            weight = 'normal'
        ax.annotate(
            xy=(positions[j], i + .5),
            text=text_label,
            ha=ha,
            va='center',
            weight=weight
        )

# Add column names
column_names = ['Player', 'Position', 'Minutes', 'Games\nPlayed', 'Starts /\nIn Squad']
for index, c in enumerate(column_names):
        if index == 0:
            ha = 'left'
        else:
            ha = 'center'
        ax.annotate(
            xy=(positions[index], nrows + .25),
            text=column_names[index],
            ha=ha,
            va='bottom',
            weight='bold'
        )

# Add dividing lines
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [nrows, nrows], lw=1.5, color='black', marker='', zorder=4)
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [0, 0], lw=1.5, color='black', marker='', zorder=4)
for x in range(1, nrows):
    ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [x, x], lw=1.15, color='gray', ls=':', zorder=3 , marker='')

ax.set_axis_off()
plt.savefig(
    'figures/pretty_example.png',
    dpi=300,
    transparent=True,
    bbox_inches='tight'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15788/3659973338.py in <module>
#      54
#      55 ax.set_axis_off()
# ---> 56 plt.savefig(
#      57     'figures/pretty_example.png',
#      58     dpi=300,
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     940 def savefig(*args, **kwargs):
#     941     fig = gcf()
# --> 942     res = fig.savefig(*args, **kwargs)
#     943     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     944     return res
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3270                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3271
# -> 3272             self.canvas.print_figure(fname, **kwargs)
#    3273
#    3274     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2336                 # force the figure dpi to 72), so we need to set it again here.
#    2337                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2338                     result = print_method(
#    2339                         filename,
#    2340                         facecolor=facecolor,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in <lambda>(*args, **kwargs)
#    2202                 "bbox_inches_restore"}
#    2203             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2204             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2205                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2206         else:  # Let third-parties do as they see fit.
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     408                          else deprecation_addendum,
#     409                 **kwargs)
# --> 410         return func(*inner_args, **inner_kwargs)
#     411
#     412     DECORATORS[wrapper] = decorator
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     518             *metadata*, including the default 'Software' key.
#     519         """
# --> 520         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     521
#     522     def print_to_buffer(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     465         """
#     466         FigureCanvasAgg.draw(self)
# --> 467         mpl.image.imsave(
#     468             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     469             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654         pil_kwargs.setdefault("format", format)
#    1655         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656         image.save(fname, **pil_kwargs)
#    1657
#    1658
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2235                 fp = builtins.open(filename, "r+b")
#    2236             else:
# -> 2237                 fp = builtins.open(filename, "w+b")
#    2238
#    2239         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figures/pretty_example.png'

# %%
df_final = df[df['Min'] >= 1000].reset_index(drop=True)
df_final = df_final[['Player', 'Nation', 'Pos', 'Min', 'MP', 'Starts', 'Subs', 'unSub']]
df_final['InSquad'] = df_final['MP'] + df_final['unSub']
df_final = df_final.sort_values(by='Min').reset_index(drop=True)
df_final = df_final[~df_final['Pos'].isna()]
df_final['Nation'] = [x.split(' ')[1].lower() for x in df_final['Nation']]
df_final['Starts_InSquad'] = [f'{x}/{y}' for x,y in zip(df_final['Starts'], df_final['InSquad'])]
df_final
# Out:
#                        Player Nation   Pos     Min  MP  Starts  Subs  unSub  \
# 0   Pierre-Emerick Aubameyang    gab    FW  1037.0  14      12     2      0
# 1        Albert Sambi Lokonga    bel    MF  1134.0  19      12     7     18
# 2                Nuno Tavares    por    DF  1176.0  22      13     9     16
# 3               Cédric Soares    por    DF  1486.0  21      16     5     12
# 4           Takehiro Tomiyasu    jpn    DF  1679.0  21      20     1      1
# 5         Alexandre Lacazette    fra  FWMF  1782.0  30      20    10      5
# 6                  Martinelli    bra  FWMF  1860.0  29      21     8      7
# 7              Kieran Tierney    sco    DF  1915.0  22      22     0      4
# 8            Emile Smith Rowe    eng  MFFW  1921.0  33      21    12      2
# 9               Thomas Partey    gha    MF  2028.0  24      23     1      0
# 10               Granit Xhaka    sui  MFDF  2327.0  27      27     0      0
# 11            Martin Ødegaard    nor    MF  2785.0  36      32     4      0
# 12                  Ben White    eng    DF  2880.0  32      32     0      2
# 13                Bukayo Saka    eng  FWMF  2978.0  38      36     2      0
# 14             Aaron Ramsdale    eng    GK  3060.0  34      34     0      2
# 15         Gabriel Dos Santos    bra    DF  3063.0  35      35     0      0
#
#     InSquad Starts_InSquad
# 0        14          12/14
# 1        37          12/37
# 2        38          13/38
# 3        33          16/33
# 4        22          20/22
# 5        35          20/35
# 6        36          21/36
# 7        26          22/26
# 8        35          21/35
# 9        24          23/24
# 10       27          27/27
# 11       36          32/36
# 12       34          32/34
# 13       38          36/38
# 14       36          34/36
# 15       35          35/35

# %%
def ax_logo(team_id, ax):
    '''
    Plots the logo of the team at a specific axes.
    Args:
        team_id (int): the id of the team according to Fotmob. You can find it in the url of the team page.
        ax (object): the matplotlib axes where we'll draw the image.
    '''
    fotmob_url = 'https://images.fotmob.com/image_resources/logo/teamlogo/'
    club_icon = Image.open(urllib.request.urlopen(f'{fotmob_url}{team_id}.png'))
    ax.imshow(club_icon)
    ax.axis('off')
    return ax

# %%
# -- Transformation functions
DC_to_FC = ax.transData.transform
FC_to_NFC = fig.transFigure.inverted().transform
# -- Take data coordinates and transform them to normalized figure coordinates
DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))
# -- Add nation axes
ax_point_1 = DC_to_NFC([2.25, 0.25])
ax_point_2 = DC_to_NFC([2.75, 0.75])
ax_width = abs(ax_point_1[0] - ax_point_2[0])
ax_height = abs(ax_point_1[1] - ax_point_2[1])
for x in range(0, nrows):
    ax_coords = DC_to_NFC([2.25, x + .25])
    flag_ax = fig.add_axes(
        [ax_coords[0], ax_coords[1], ax_width, ax_height]
    )
    ax_logo(df_final['Nation'].iloc[x], flag_ax)

# %%
def minutes_battery(minutes, ax):
    '''
    This function takes an integer and an axes and 
    plots a battery chart.
    '''
    ax.set_xlim(0,1)
    ax.set_ylim(0,1)
    ax.barh([0.5], [1], fc = 'white', ec='black', height=.35)
    ax.barh([0.5], [minutes/(90*38)], fc = '#D2042D', height=.35)
    text_ = ax.annotate(
        xy=(minutes/(90*38), .5),
        text=f'{minutes/(90*38):.0%}',
        xytext=(-8,0),
        textcoords='offset points',
        weight='bold',
        color='#EFE9E6',
        va='center',
        ha='center',
        size=5
    )
    ax.set_axis_off()
    return ax

# %%
fig = plt.figure(figsize=(8,10), dpi=300, facecolor = 'black')
ax = plt.subplot()
mpl.rc('text', color='white')


ncols = 6
nrows = df_final.shape[0]

ax.set_xlim(0, ncols + 1)
ax.set_ylim(0, nrows + 1)

positions = [0.10, 3.5, 4.5, 5.5, 6.5]
columns = ['Player', 'Pos', 'Min', 'MP', 'Starts_InSquad']

# -- Add table's main text
for i in range(nrows):
    for j, column in enumerate(columns):
        if j == 0:
            ha = 'left'
        else:
            ha = 'center'
        if column == 'Min':
            continue
        else:
            text_label = f'{df_final[column].iloc[i]}'
            weight = 'normal'
        ax.annotate(
            xy=(positions[j], i + .5),
            text=text_label,
            ha=ha,
            va='center',
            weight=weight
        )

# -- Transformation functions
DC_to_FC = ax.transData.transform
FC_to_NFC = fig.transFigure.inverted().transform
# -- Take data coordinates and transform them to normalized figure coordinates
DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))
# -- Add nation axes
ax_point_1 = DC_to_NFC([2.25, 0.25])
ax_point_2 = DC_to_NFC([2.75, 0.75])
ax_width = abs(ax_point_1[0] - ax_point_2[0])
ax_height = abs(ax_point_1[1] - ax_point_2[1])
for x in range(0, nrows):
    ax_coords = DC_to_NFC([2.25, x + .25])
    flag_ax = fig.add_axes(
        [ax_coords[0], ax_coords[1], ax_width, ax_height]
    )
    ax_logo(df_final['Nation'].iloc[x], flag_ax)

ax_point_1 = DC_to_NFC([4, 0.05])
ax_point_2 = DC_to_NFC([5, 0.95])
ax_width = abs(ax_point_1[0] - ax_point_2[0])
ax_height = abs(ax_point_1[1] - ax_point_2[1])
for x in range(0, nrows):
    ax_coords = DC_to_NFC([4, x + .025])
    bar_ax = fig.add_axes(
        [ax_coords[0], ax_coords[1], ax_width, ax_height]
    )
    minutes_battery(df_final['Min'].iloc[x], bar_ax)

# -- Add column names
column_names = ['Player', 'Position', '% of Min.\nPlayed', 'Games\nPlayed', 'Starts/\nIn Squad']
for index, c in enumerate(column_names):
        if index == 0:
            ha = 'left'
        else:
            ha = 'center'
        ax.annotate(
            xy=(positions[index], nrows + .25),
            text=column_names[index],
            ha=ha,
            va='bottom',
            weight='bold'
        )

# Add dividing lines
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [nrows, nrows], lw=1.5, color='white', marker='', zorder=4)
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [0, 0], lw=1.5, color='white', marker='', zorder=4)
for x in range(1, nrows):
    ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [x, x], lw=1.15, color='white', ls=':', zorder=3 , marker='')

ax.fill_between(
    x=[0,3],
    y1=nrows,
    y2=0,
    color='white',
    alpha=0.5,
    ec='red'
)

ax.set_axis_off()
# -- Final details
logo_ax = fig.add_axes(
    [0.825, 0.89, .05, .05]
)
ax_logo(9825, logo_ax)
fig.text(
    x=0.15, y=.91,
    s='Arsenal 2021/2022 Squad Playing Time',
    ha='left',
    va='bottom',
    weight='bold',
    size=12
)
plt.savefig(
    'figures/final_table.png',
    dpi=300,
    transparent=True,
    bbox_inches='tight'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15788/318274982.py in <module>
#     105     size=12
#     106 )
# --> 107 plt.savefig(
#     108     'figures/final_table.png',
#     109     dpi=300,
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     940 def savefig(*args, **kwargs):
#     941     fig = gcf()
# --> 942     res = fig.savefig(*args, **kwargs)
#     943     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     944     return res
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3270                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3271
# -> 3272             self.canvas.print_figure(fname, **kwargs)
#    3273
#    3274     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2336                 # force the figure dpi to 72), so we need to set it again here.
#    2337                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2338                     result = print_method(
#    2339                         filename,
#    2340                         facecolor=facecolor,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in <lambda>(*args, **kwargs)
#    2202                 "bbox_inches_restore"}
#    2203             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2204             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2205                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2206         else:  # Let third-parties do as they see fit.
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     408                          else deprecation_addendum,
#     409                 **kwargs)
# --> 410         return func(*inner_args, **inner_kwargs)
#     411
#     412     DECORATORS[wrapper] = decorator
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     518             *metadata*, including the default 'Software' key.
#     519         """
# --> 520         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     521
#     522     def print_to_buffer(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     465         """
#     466         FigureCanvasAgg.draw(self)
# --> 467         mpl.image.imsave(
#     468             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     469             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654         pil_kwargs.setdefault("format", format)
#    1655         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656         image.save(fname, **pil_kwargs)
#    1657
#    1658
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2235                 fp = builtins.open(filename, "r+b")
#    2236             else:
# -> 2237                 fp = builtins.open(filename, "w+b")
#    2238
#    2239         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figures/final_table.png'
